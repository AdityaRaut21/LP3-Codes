# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def function(x):
    #The function we want to minimize: f(x) = (x+3)**2
    return (x + 3)**2

# %%
def derivative(x):
    #Derivative of the function: f'(x) = 2(x+3)
    return 2 * (x + 3)

# %%
def gradient_descent(start_x, learning_rate, num_iterations):
    #Performs gradient descent to find local minima
    points = []
    x = start_x

    for _ in range(num_iterations):
        points.append((x, function(x)))
        gradient = derivative(x)
        x = x - learning_rate * gradient

    return np.array(points)

# %%
start_x = 2
learning_rate = 0.1
num_iterations = 20

# %%
points = gradient_descent(start_x, learning_rate, num_iterations)

# %%
x = np.linspace(-5, 5, 100)
y = function(x)

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', label='f(x) = (x+3)^2')
plt.plot(points[:, 0], points[:, 1], 'ro-', label='Gradient Descent Path')
plt.grid = True
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title("Gradient Descent Optimization")
plt.legend()
plt.show()

# %%
print(f"Starting Point: x = {start_x}, f(x) = {function(start_x):.2f}")
print(f"Final Point: x = {points[-1, 0]:.4f}, f(x) = {points[-1, 1]:.4f}")
# Out:
# Starting Point: x = 2, f(x) = 25.00
# Final Point: x = -2.9279, f(x) = 0.0052
